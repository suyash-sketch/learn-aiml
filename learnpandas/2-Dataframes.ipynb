# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Creating Dataframe

# %%
data = {
    'Name' : ['john', 'anna', 'peter', 'linda'],
    'Age' : [28,34,29,20],
    'City' : ['new york', 'paris', 'berlin', 'london'],
    'Salary' : [65000, 70000, 62000, 85000]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   john   28  new york   65000
# 1   anna   34     paris   70000
# 2  peter   29    berlin   62000
# 3  linda   20    london   85000

# %%
data_list = [
    [ 'john', 28, 'new york', 65000],
    [ 'anna',34, 'paris', 70000],
    [ 'peter',29, 'berlin', 62000], 
    [ 'linda', 20, 'london', 85000]
]

df2 = pd.DataFrame(data_list, columns=['Name', 'Age', 'City','Salary'])

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   john   28  new york   65000
# 1   anna   34     paris   70000
# 2  peter   29    berlin   62000
# 3  linda   20    london   85000

# %% [markdown]
# ## Selection and indexing of column

# %%
df[['Name', 'City']]
# Out:
#     Name      City
# 0   john  new york
# 1   anna     paris
# 2  peter    berlin
# 3  linda    london

# %% [markdown]
# ## Creating a new column

# %%
df['Designation'] = ['Doctor','Engineer','IAS', 'Headmaster']

# %%
df
# Out:
#     Name  Age      City  Salary Designation
# 0   john   28  new york   65000      Doctor
# 1   anna   34     paris   70000    Engineer
# 2  peter   29    berlin   62000         IAS
# 3  linda   20    london   85000  Headmaster

# %% [markdown]
# ## Removing a column

# %%
df.drop('Designation',axis= 1, inplace=True)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   john   28  new york   65000
# 1   anna   34     paris   70000
# 2  peter   29    berlin   62000
# 3  linda   20    london   85000

# %% [markdown]
# ## Selecting rows

# %%
df.loc[1]
# Out:
# Name       anna
# Age          34
# City      paris
# Salary    70000
# Name: 1, dtype: object

# %% [markdown]
# ## Selecting subsets of rows and column

# %%
df.loc[[0,1]][['City', 'Salary']]
# Out:
#        City  Salary
# 0  new york   65000
# 1     paris   70000

# %%
df.loc[[2,3]][['Name', 'Age']]
# Out:
#     Name  Age
# 2  peter   29
# 3  linda   20

# %% [markdown]
# ### Conditional Selection

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   john   28  new york   65000
# 1   anna   34     paris   70000
# 2  peter   29    berlin   62000
# 3  linda   20    london   85000

# %%
df[df['Age'] > 28]
# Out:
#     Name  Age    City  Salary
# 1   anna   34   paris   70000
# 2  peter   29  berlin   62000

# %%
# people whose age is above 30 and lives in paris
df[(df['Age'] > 30) & (df['City'] == 'paris')]
# Out:
#    Name  Age   City  Salary
# 1  anna   34  paris   70000
