# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# Load dataset
df = pd.read_csv('IPL.csv')
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %% [markdown]
# **Basic Information**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
df.describe()
# Out:
#         match_id  first_ings_score  first_ings_wkts  second_ings_score  \
# count  74.000000         74.000000        74.000000          74.000000
# mean   37.500000        171.121622         6.135135         158.540541
# std    21.505813         29.048355         2.222699          29.299207
# min     1.000000         68.000000         0.000000          72.000000
# 25%    19.250000        154.250000         5.000000         142.750000
# 50%    37.500000        169.500000         6.000000         160.000000
# 75%    55.750000        192.750000         8.000000         176.000000
# max    74.000000        222.000000        10.000000         211.000000
#
#        second_ings_wkts     margin   highscore
# count         74.000000  74.000000   74.000000
# mean           6.175676  16.972973   71.716216
# std            2.639832  19.651047   20.705052
# min            1.000000   2.000000   28.000000
# 25%            4.000000   5.250000   57.000000
# ...

# %%
df.shape
# Out:
# (74, 20)

# %%
df.isnull().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
# which team won the most matches
match_wins = df['match_winner'].value_counts()
match_wins
plt.figure(figsize=(12,8))
sns.barplot(x=match_wins.index, y=match_wins.values, palette='viridis')
# Out:
# <Axes: xlabel='match_winner'>

# %%
fig = px.bar(x=match_wins.index, y=match_wins.values, color=match_wins.index)
fig.show()

# %%
# 2. Toss decision head
sns.countplot(x=df['toss_decision'])
# Out:
# <Axes: xlabel='toss_decision', ylabel='count'>

# %%
tosses = df['toss_decision'].value_counts()
tosses
# Out:
# toss_decision
# Field    59
# Bat      15
# Name: count, dtype: int64

# %%
px.bar(x=tosses.index, y=tosses.values, labels={ 'x' :'decions', 'y' : 'count'}, color=tosses.index)

# %%
# 3. Toss Winner vs Match Winner
winner_count = df[df['toss_winner'] == df['match_winner']]['toss_winner'].value_counts()

# %%
px.bar(x=winner_count.index, y=winner_count.values, color=winner_count.index, labels={'x': 'won toss', 'y' : 'number of times won matches'})

# %%
# 4. How do teams win( by Runs vs Wicket)
won_by = df['won_by'].value_counts()
px.bar(x=won_by.index, y=won_by.values, labels={'x':'won by','y' : 'wins'}, color=won_by.index)

# %% [markdown]
# ### Key Player Performances

# %% [markdown]
# 1. Most "player of the match" awards

# %%
count = df['player_of_the_match'].value_counts().head(10)
count
# Out:
# player_of_the_match
# Kuldeep Yadav        4
# Jos Buttler          3
# Wanindu Hasaranga    2
# Umesh Yadav          2
# Quinton de Kock      2
# Shubman Gill         2
# Avesh Khan           2
# Dinesh Karthik       2
# Hardik Pandya        2
# Rahul Tripathi       2
# Name: count, dtype: int64

# %%
px.bar(x=count.index, y=count.values, color=count.values)

# %% [markdown]
# 2.  Top Scorer

# %%
top_scorers = df['top_scorer'].value_counts().head(10)
top_scorers
# Out:
# top_scorer
# Jos Buttler         7
# Quinton de Kock     5
# Liam Livingstone    4
# Shubman Gill        4
# KL Rahul            4
# Ishan Kishan        3
# David Warner        3
# W. Saha             3
# Faf du Plessis      3
# Shikhar Dhawan      2
# Name: count, dtype: int64

# %%
px.bar(x=top_scorers.index, y=top_scorers.values, color=top_scorers.values)

# %% [markdown]
# 3. 10 Best Bowling Figure

# %%
# Extracting the number of wickets from best_bowling_figures

df['highest_wickets'] = df['best_bowling_figure'].apply(lambda x : x.split('--')[0])
df['highest_wickets'] = df['highest_wickets'].astype(int)

top_bowlers = df.groupby('best_bowling')['highest_wickets'].sum().sort_values(ascending=False).head(10)
top_bowlers
px.bar(x=top_bowlers.index, y=top_bowlers.values, color=top_bowlers.values, 
       labels={'x' : 'top_bowlers', 'y' : 'number of wickets'})

# %% [markdown]
# #### Venue Analysis

# %% [markdown]
# Most Matches Played by Venue

# %%
venue = df['venue'].value_counts()
venue
px.bar(x=venue.index, y=venue.values, color=venue.index)

# %%
# who won by the highest margins by Runs
df[ df['won_by'] == 'Runs' ].sort_values(by='margin',ascending=False).head(1)[['match_winner', 'margin']]
# Out:
#    match_winner  margin
# 54      Chennai      91

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  ...  second_ings_wkts  match_winner   won_by margin  \
# ...

# %%
# Which player has the highest individual score in one match

# high = df.groupby('top_scorer')['highscore'].sum().sort_values(ascending=False).head(1)
# high

df[df['highscore'] == df['highscore'].max()]
# Out:
#     match_id         date                               venue    team1  \
# 65        66  May 18,2022  Dr DY Patil Sports Academy, Mumbai  Kolkata
#
#       team2  stage toss_winner toss_decision  first_ings_score  \
# 65  Lucknow  Group     Lucknow           Bat               210
#
#     first_ings_wkts  ...  second_ings_wkts  match_winner won_by margin  \
# 65                0  ...                 8       Lucknow   Runs      2
#
#     player_of_the_match       top_scorer highscore  best_bowling  \
# 65      Quinton de Kock  Quinton de Kock       140   Mohsin Khan
#
#    best_bowling_figure highest_wickets
# 65               3--20               3
#
# [1 rows x 21 columns]

# %%
# Which Player has the best bowling figure
df[df['highest_wickets'] == df['highest_wickets'].max()][['best_bowling', 'best_bowling_figure']]
# Out:
#          best_bowling best_bowling_figure
# 29   Yuzvendra Chahal               5--40
# 39        Umran Malik               5--25
# 53  Wanindu Hasaranga               5--18
# 55     Jasprit Bumrah               5--10
