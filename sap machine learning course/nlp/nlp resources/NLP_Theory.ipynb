# %% [markdown]
# #   <font color = darkblue size =6.5><center> NLP : Natural Language Processing

# %% [raw]
# 1. We talk to eachother in multiple languages. we are talking in Hindi,marathi so this is a natural language.
#    Human will understand this language.
#
# 2. But machine cannot understand this natural language. In NLP, we make the machine capable to understand
#    the natural language.

# %% [markdown]
# ## 2 components of NLP

# %%
1. Natural language understanding - In this machine will understand meaning of each and every word.

2. Natural language generation - process of transforming data into natural language using artificial intelligence.

# %% [markdown]
# ##  Popular Application Of NLP

# %% [markdown]
# <font color = darkblue size =4>1. Sentiment Analysis

# %% [raw]
# 1. In this we find sentiment of a word whether that word is good or bad.
#
# 2. when we message something on social media, from that messgage we can predict
#    sentiment of that person means what that person want to say or mood of that person.
#
# 3. eg. Twitter - If some politics topic is in trend then some will give hatred tweet,
#        some will give neutral tweet and some will give positive tweet.So we will classify
#        this tweets.This will be multinomial classification as there are 3 values in
#        target columns.
#
#     eg. Movie reviews - Positive review, negative review and neutral review. so we classify
#         the movie reviews.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <font color = darkblue size =4>2. Topic Identification

# %% [raw]
# 1. Consider if there are 100 documents and i dont know what are this document related to or
#    what is there in this documents.
#
# 2. If there is 1 page document then we can understand the topic easily. If some document is
#    of 500 pages so it is difficult to read all pages and understand the topic of the document.
#    so topic of this document is identified using algorithms.

# %% [markdown]
# <font color = darkblue size =4>3. Named Entity Recognition(NER)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 1. Named entity recognition (NER) is the task of tagging entities in text with their corresponding type.
#
# 2. eg. Resume parser - we are applying for a job on Naukri and submit our Resume to HR. HR will not read
#        each and every resume. he uses one application called resume parser which uses NER technique.
#
#        Rajesh was learning python and working in KPIT.
#        NER will give name tag in front of Rajesh, skillset tag in front of python and company tag in front
#        of KPIT.

# %% [markdown]
# <font color = darkblue size =4>4. Translation

# %% [raw]
# 1. eg. Google translator - suppose you have written a sentence in Tamil and you want
#        to convert that sentence into english. first the machine will identify in which
#        language the sentence is written. After identification of language, machine will check
#        which is the target language. In this case the target language is english.
#
#        In that translator, a machine learning model is build which will process the tamil
#        language and then convert it into english language.
#
# Translation has 2 things:
#     1. language identification
#     2. Language translation

# %% [markdown]
# <font color = darkblue size =4>5. Chatbots

# %% [raw]
# 1. In many applications like Myntra shopping, amazon shopping etc. there is a automatic
#    generated message at the right side bottom this is called as a chatbot. It gives
#    service to the customer 24x7.
#
# 2. Model is trained and then it will predict the output. Model will learn if this type of
#    input is there then when should be the output.

# %% [markdown]
# <font color = darkblue size =4>6. Voice Assistant

# %% [raw]
# 1. eg.Siri, Alexa, or Google Assistant, microsoft cortana. this apps are used to
#    make calls, place reminders, schedule meetings, set alarms, surf the internet, etc.
#
#    steps in voice assistant
#    1. Speech recognition
#    2. Speech to text conversion, preprocessing the text.
#    3. Text to speech conversion

# %% [markdown]
# <font color = darkblue size =4>7. Document summarization

# %% [raw]
# 1. It is the task of rewriting a document into its shorter form while still retaining
#    its important content.
#
# 2. eg. When we are searching something on Google, then a small blog of news of 20-30 lines
#        (short description)appear at the bottom. Everyone is lazy and they will not read entire
#        news so that entire page is converted into 20-30 lines by using document summarization.

# %% [markdown]
# <font color = darkblue size =4>8. Text generation

# %%
1. In this the machine will directly generate some text on its own.

2. eg. If we are asking some questions to the robot, then it will generate some results.
       Machine can write novels,song lyrics etc. on its own.

# %% [markdown]
# ## Libraries for working in NLP

# %% [markdown]
# <font color = darkblue size =3>1.1.NLTK - Natural Language Tool Kit
# ___
# <font color = darkblue size =3>1.2.Gensim
# ___
# <font color = darkblue size =3>1.3.Spacy
# ___
# <font color = darkblue size =3>1.4.Rasa

# %% [markdown]
# #   <font color = darkblue size =5> Installing Important Libraries

# %% [markdown]
# !pip install --user -U nltk
# !pip install gensim
#
# for installing spacy
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_core_web_sm

# %%
import pandas as pd 
df = pd.read_csv(r'C:\Users\DELL\Documents\NLP\Train.csv')
df
# Out:
#                                                     text  label
# 0      I grew up (b. 1965) watching and loving the Th...      0
# 1      When I put this movie in my DVD player, and sa...      0
# 2      Why do people who do not know what a particula...      0
# 3      Even though I have great interest in Biblical ...      0
# 4      Im a die hard Dads Army fan and nothing will e...      1
# ...                                                  ...    ...
# 39995  "Western Union" is something of a forgotten cl...      1
# 39996  This movie is an incredible piece of work. It ...      1
# 39997  My wife and I watched this movie because we pl...      0
# 39998  When I first watched Flatliners, I was amazed....      1
# 39999  Why would this film be so good, but only gross...      1
#
# [40000 rows x 2 columns]

# %% [markdown]
# #   <font color = darkblue size =5><center>NLP Pipeline

# %% [markdown]
# #   <font color = darkblue size =3>1. Data Collection <br><br>2.Text Wrangling and Preprocessing <br><br>3.Vectorization and Feature Engineering<br><br>4.Model Building and Initialization<br> <br>5.Train and Test Model<br><br>6.Model Evaluation<br><br>7.Deployment<br><br>8.Monitoring and Model Updating

# %% [markdown]
# # 1. Data collection

# %%
1. Generally text data is not available easily. If it is available, then we will not get it continuously.
   We face many problems while data collection.

2. If we get the data then we have to check the quality of the data.

# %% [markdown]
# ![Flowchart.jfif](attachment:Flowchart.jfif)

# %% [markdown]
# # 2.Text Preprocessing Techniques

# %% [raw]
# Preprocessing means removing noise from the data. we cannot give raw data directly to the model.
# so we have to remove the unwanted things from the text data.

# %% [markdown]
# ![preprocessing.jfif](attachment:preprocessing.jfif)

# %% [markdown]
# <font color = darkblue size =3>2.1.Tokenization
# ___
# <font color = darkblue size =3>2.2. Cleaning
# ___
# <font color = darkblue size =3>2.3. Normalization
# ___
# <font color = darkblue size =3>2.4. Stop Words Removal
# ___
# <font color = darkblue size =3>2.5. Stemming and  Lemmatization
# ___
# <font color = darkblue size =3>2.6. POS Tagging
# ___
# <font color = darkblue size =3>2.7. Named Entity Reconition

# %% [markdown]
# ## 2.1 Tokenization

# %% [raw]
# 1. Tokenization is a way of separating a piece of text into smaller units called tokens.
#
# 2. It consists of 2 things:
#    1. Sentence tokenization - It will return a list of sentences in entire text.
#    2. Word tokenization - It will return a list of all words in a text.
#
#    If the text is split into words, then its called as 'Word Tokenization' and if it's
#    split into sentences then its called as 'Sentence Tokenization'.
#
# "I i am learning python $ $ 888 and NLP. ETLhive is organization" :
#
# sentences = ['I am learning python $ $ 888 and NLP', 'ETLhive is organization']
# words = [I, am ,learning,python,$,888]
#
#
# row 1 = 'Movie was great? +++++I liked sharukh.>>> Actors were great,thrilling.'
#
# tokenizaation : sentence tokenization :['Movie was great?','+++++I liked sharukh.','>>> Actors were great,thrilling.']
#                 word tokenization : ['Movie','was','great','?'........etc]

# %% [markdown]
# # 2.2 Cleaning

# %% [raw]
# 1. Cleaning means removing unwanted symbols(!$%&#), unwanted pattern, extra space from the text.
#    This can be done using the regular expressions.
#
# 2. eg. If we are working in banking domain, then account number and birth date of candidate
#        is important. So we have to create some regular expressions to extract this account no & DOB.

# %% [markdown]
# # 2.3 Normalization

# %% [raw]
# 1. Normalization means converting uppercase text into lowercase.
#
# eg. great and GREAT - Machine doesnot recognize this 2 words as same.
#     Machine will understand this 2 words are different. so to avoid ambiguity
#     to machine we have to convert the entire text into lowercase.

# %% [markdown]
# # 2.4 Stopwords removal

# %% [raw]
# 1. Stop words are a set of commonly used words in any language.
#    There are stopwords of every language eg. hindi language, english language.
#
# 2. stop words are used to eliminate unimportant words, allowing applications to
#    focus on the important words instead.
#
# Types of stopwords:
# 1. Gramatical stopwords/ Language specific stopwords : This are the words that
#    make the sentence gramatically correct. We have to remove this stopwords from
#    the sentence.
#    English language stopwords - was,were,not,did,didnot,I,Iam,the,is,isnot,could,couldnot etc.
#
#    eg. Movie was great - If we dont write 'was' then also we can understand the meaning of
#        that sentence.
#
# 2. Domain specific stopwords: There are some generalized words(common words) in any domain.
#    If we remove this words from a sentence then also there will not be huge impact on that sentence.
#
#    eg. Healthcare domain stopwords - doctor,nurse,medicine,tablet etc.
#
#        Banking domain stopwords - cheque,account,money,cash,transaction,slip etc.

# %% [markdown]
# # 2.5 Stemming and Lemmatization

# %% [markdown]
# ## 1.Stemming

# %% [raw]
# prunning : getting a root word of a particular word
# stemming : aggressive prunner (stem : root word)
#
#     walking  >>  walk
#     learning >> learn
#
# stemming is an aggresive prunner, means it cut the suffix of the words. It will
# not see whether we are getting a meaningfull word or not after removing the suffix.

# %% [markdown]
# ## 2.Lemmatization

# %%
lemmatization : (lemma : meaningful root word)
    learning >> learning
   
If we are giving some input to lemmatization then it will see whether there
is some meaning to that word or not.If there is meaning to that word in dictionary,
then it will not prune that word. If there is no meaning to that word in dictionary,
then it will prune that word.

# %% [markdown]
# ## which one to use when

# %% [raw]
# we cannot say stemming is better or lemmatization is better.It depend on the data
# that we have. Out of the stemming and lemmatization, we will use that technique
# to build the model which will give good results.
#
# Most of the times stemming is better than lemmatization. Most of the times lemmatization
# will not do anything, input will be same as output. eg. Learning >> Learning.
# stemming will perform well in this case because it will remove characters.eg. Learning >> Learn
#
# our main goal is to get proper meaning and remove characters.

# %% [raw]
# eg. walking - 7 char
#     walk - 4 char
#
# If walk is fulfilling the purpose then why use walking. Walking se characters increase ho rahe he.
# agar charcaters kaam rahega to hum jyada words de payenge model ko. jitna jyada data denge model ko
# wo utna accha perform karega but we have to give important and useful data.

# %% [markdown]
# ## Difference between Stemming and Lemmatization

# %% [raw]
# Stemming:
# 1. Process of converting each words of a sentence to its root form by deleting
#    or removing suffixes.
#
# 2. It is faster.
#
# 3. We dont consider the context of a word.
#
# 4. It dont check meaning of a word.
#
# 5. We dont consider POS tagging
#
# 6. Application - Sentiment analysis, Gmail spam filter etc.

# %% [raw]
# Lemmatization:
# 1. Process of finding meaningfull root word is called as lemmatization.
#    not prune the word - meaning is in dictionary
#    prune the word - meaning is not in dictionary
#
# 2. It is slower.
#
# 3. We  understand/consider the context of a word.
#
# 4. It check meaning of a word.
#
# 5. We consider POS tagging
#
# 6. Application - Chatbot, Question answering application etc.

# %% [markdown]
# ## Disadvantages of stemming and lemmatization

# %%
It doesnt support majority of languages.It dont give performance on most of the languages.
so we have to build stemming tool and lemmatization tool depending upon the language that 
we have.

# In interview you can say that i have worked on english language so i dont get that problem.
