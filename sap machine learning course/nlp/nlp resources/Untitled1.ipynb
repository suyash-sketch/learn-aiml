# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a1 = np.array([1,2,3,4])
a2 =1/ (1 + np.exp(a1))

# %%
plt.xlabel("x-axis")
plt.ylabel('y-axis')
plt.title("Linearity Plot")
plt.plot(a1,a2)

# %%
y = mx + c

# %%
a1 = np.array([4,3,2,1])
a2 = np.array([11,22,33,44])

# %%
plt.xlabel("x-axis")
plt.ylabel('y-axis')
plt.title("Linearity Plot")
plt.plot(a1,a2)

# %%
df=pd.read_csv(r"C:\Users\A1\Downloads\MOCK_DATA (1).csv")
df.head()
# Out:
#    id first_name    last_name                   email  gender      ip_address  \
# 0   1    Esteban       Emmins      eemmins0@tmall.com    Male    41.39.31.243
# 1   2      Sande       Romayn        sromayn1@nba.com  Female   122.160.16.61
# 2   3        Fax  MacCostigan  fmaccostigan2@ehow.com    Male   135.20.244.32
# 3   4      Franz   Wilkennson   fwilkennson3@dell.com    Male  218.82.107.119
# 4   5     George     Twinbrow      gtwinbrow4@npr.org  Female    125.85.135.2
#
#     state
# 0  Alaska
# 1  Alaska
# 2  Alaska
# 3  Alaska
# 4  Alaska

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.ndim
# Out:
# 2

# %%
df.describe(include='object')
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
df.describe(exclude='number')
# Out:
#          sex embarked  class  who adult_male deck  embark_town alive alone
# count    891      889    891  891        891  203          889   891   891
# unique     2        3      3    3          2    7            3     2     2
# top     male        S  Third  man       True    C  Southampton    no  True
# freq     577      644    491  537        537   59          644   549   537

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# # Missing_Columns

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# # Treating_Missing_Records

# %%
df["age"].mean()
# Out:
# 29.69911764705882

# %%
df["age"].median()
# Out:
# 28.0

# %%
df["age"]=df["age"].fillna(28.0)

# %%
df["age"].isnull().sum()
# Out:
# 0

# %%
del df["deck"]

# %%
df.shape
# Out:
# (891, 14)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (889, 14)

# %%
df.duplicated().sum()
# Out:
# 116

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
df["age"]=df["age"].astype(int)
df["age"][:2]
# Out:
# C:\Users\A1\jupyter\Lib\site-packages\pandas\core\dtypes\astype.py:133: ComplexWarning: Casting complex values to real discards the imaginary part
#   return arr.astype(dtype, copy=True)
# 0    22
# 1    38
# Name: age, dtype: int32

# %%
df["fare"]=df["fare"].round(2)
df["fare"][:2]
# Out:
# 0     7.25
# 1    71.28
# Name: fare, dtype: float64

# %%
#df.rename(columns={"A": "a", "B": "c"})
df.rename(columns={"class":"CLASS"},inplace=True)
#

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
df["age"].value_counts(bins=5)
# Out:
# (16.0, 32.0]      525
# (32.0, 48.0]      185
# (-0.081, 16.0]    100
# (48.0, 64.0]       68
# (64.0, 80.0]       11
# Name: count, dtype: int64

# %%
df["who"].value_counts()
# Out:
# who
# man      537
# woman    269
# child     83
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label=LabelEncoder()
df["who"]=label.fit_transform(df["who"])

# %%
df["who"][:4]
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# Name: who, dtype: int32

# %%
df["who"].value_counts()
# Out:
# who
# 1    537
# 2    269
# 0     83
# Name: count, dtype: int64

# %% [markdown]
# # EDA

# %%
df1=df.select_dtypes("number")

# %%
df1.corr()
# Out:
#           survived    pclass       age     sibsp     parch      fare       who
# survived  1.000000 -0.335549 -0.069821 -0.034040  0.083151  0.255289  0.323191
# pclass   -0.335549  1.000000 -0.336612  0.081656  0.016824 -0.548190 -0.193029
# age      -0.069821 -0.336612  1.000000 -0.232312 -0.171749  0.093855  0.348315
# sibsp    -0.034040  0.081656 -0.232312  1.000000  0.414542  0.160889 -0.134887
# parch     0.083151  0.016824 -0.171749  0.414542  1.000000  0.217537 -0.054389
# fare      0.255289 -0.548190  0.093855  0.160889  0.217537  1.000000  0.143847
# who       0.323191 -0.193029  0.348315 -0.134887 -0.054389  0.143847  1.000000

# %%
sns.heatmap(df1.corr(),annot=True)
# Out:
# <Axes: >
