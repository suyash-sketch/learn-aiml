# %%
# Install SpaCy (if not already installed)
# !pip install spacy

# Download the small English model
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\akshay\anaconda3\lib\site-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (2.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (2.10.3)
# Requirement already satisfied: jinja2 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\akshay\anaconda3\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\akshay\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\akshay\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\akshay\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\akshay\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\akshay\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akshay\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akshay\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akshay\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.4.26)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\akshay\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\akshay\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\akshay\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\akshay\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\akshay\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.22.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\akshay\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.3.1)
# Requirement already satisfied: wrapt in c:\users\akshay\anaconda3\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\akshay\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\akshay\anaconda3\lib\site-packages (from jinja2->spacy) (3.0.2)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 4.9 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.3/12.8 MB 4.3 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.6/12.8 MB 2.7 MB/s eta 0:00:05
#      ----- ---------------------------------- 1.8/12.8 MB 2.1 MB/s eta 0:00:06
#      ----- ---------------------------------- 1.8/12.8 MB 2.1 MB/s eta 0:00:06
#      ------ --------------------------------- 2.1/12.8 MB 1.7 MB/s eta 0:00:07
#      ------- -------------------------------- 2.4/12.8 MB 1.6 MB/s eta 0:00:07
#      -------- ------------------------------- 2.6/12.8 MB 1.5 MB/s eta 0:00:07
#      --------- ------------------------------ 2.9/12.8 MB 1.5 MB/s eta 0:00:07
#      --------- ------------------------------ 3.1/12.8 MB 1.5 MB/s eta 0:00:07
#      ---------- ----------------------------- 3.4/12.8 MB 1.4 MB/s eta 0:00:07
#      ---------- ----------------------------- 3.4/12.8 MB 1.4 MB/s eta 0:00:07
#      ------------ --------------------------- 3.9/12.8 MB 1.4 MB/s eta 0:00:07
#      ------------- -------------------------- 4.2/12.8 MB 1.4 MB/s eta 0:00:07
#      ------------- -------------------------- 4.5/12.8 MB 1.4 MB/s eta 0:00:06
#      -------------- ------------------------- 4.7/12.8 MB 1.4 MB/s eta 0:00:06
#      --------------- ------------------------ 5.0/12.8 MB 1.4 MB/s eta 0:00:06
#      --------------- ------------------------ 5.0/12.8 MB 1.4 MB/s eta 0:00:06
#      ---------------- ----------------------- 5.2/12.8 MB 1.3 MB/s eta 0:00:06
#      ----------------- ---------------------- 5.5/12.8 MB 1.3 MB/s eta 0:00:06
#      ------------------ --------------------- 5.8/12.8 MB 1.3 MB/s eta 0:00:06
#      ------------------ --------------------- 5.8/12.8 MB 1.3 MB/s eta 0:00:06
#      ------------------ --------------------- 5.8/12.8 MB 1.3 MB/s eta 0:00:06
#      ------------------ --------------------- 6.0/12.8 MB 1.2 MB/s eta 0:00:06
#      -------------------- ------------------- 6.6/12.8 MB 1.2 MB/s eta 0:00:06
#      --------------------- ------------------ 6.8/12.8 MB 1.2 MB/s eta 0:00:05
#      ---------------------- ----------------- 7.1/12.8 MB 1.2 MB/s eta 0:00:05
#      ----------------------- ---------------- 7.6/12.8 MB 1.3 MB/s eta 0:00:05
#      -------------------------- ------------- 8.4/12.8 MB 1.3 MB/s eta 0:00:04
#      ---------------------------- ----------- 9.2/12.8 MB 1.4 MB/s eta 0:00:03
#      ------------------------------ --------- 9.7/12.8 MB 1.5 MB/s eta 0:00:03
#      -------------------------------- ------- 10.5/12.8 MB 1.5 MB/s eta 0:00:02
#      -------------------------------- ------- 10.5/12.8 MB 1.5 MB/s eta 0:00:02
#      -------------------------------- ------- 10.5/12.8 MB 1.5 MB/s eta 0:00:02
#      --------------------------------- ------ 10.7/12.8 MB 1.5 MB/s eta 0:00:02
#      ---------------------------------- ----- 11.0/12.8 MB 1.4 MB/s eta 0:00:02
#      ---------------------------------- ----- 11.0/12.8 MB 1.4 MB/s eta 0:00:02
#      ---------------------------------- ----- 11.0/12.8 MB 1.4 MB/s eta 0:00:02
#      ----------------------------------- ---- 11.3/12.8 MB 1.4 MB/s eta 0:00:02
#      ------------------------------------ --- 11.5/12.8 MB 1.4 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.8 MB 1.4 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 1.3 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 1.3 MB/s eta 0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

# Load the English NLP model
nlp = spacy.load("en_core_web_sm")

# %%
# IPL 2025 match details
text = """
The Delhi government will launch a sterilisation and vaccination drive campaign under the Animal Birth Control (ABC) Rules 2023 after the Supreme Court orders on stray dogs. The Supreme Court ordered that the stray dogs must be released after sterilisation and immunisation, except those infected with rabies or exhibiting aggressive behaviour.
"""

# %%
# Process the text using the SpaCy NLP pipeline
doc = nlp(text)
doc
# Out:
# The Delhi government will launch a sterilisation and vaccination drive campaign under the Animal Birth Control (ABC) Rules 2023 after the Supreme Court orders on stray dogs. The Supreme Court ordered that the stray dogs must be released after sterilisation and immunisation, except those infected with rabies or exhibiting aggressive behaviour.

# %%
print("Named Entities in the IPL 2025 Text:\n")
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")
# Out:
# Named Entities in the IPL 2025 Text:
#
# Delhi -> GPE
# the Animal Birth Control -> ORG
# ABC -> ORG
# 2023 -> DATE
# the Supreme Court -> ORG
# The Supreme Court -> ORG

# %%
from spacy import displacy

# Visualizing the named entities
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>The
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Delhi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  government will launch a sterilisation and vaccination drive campaign under
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Animal Birth Control
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ABC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) Rules
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Supreme Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  orders on stray dogs.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Supreme Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ordered that the stray dogs must be released after sterilisation and immunisation, except those infected with rabies or exhibiting aggressive behaviour.<br></div></span>

# %%
# Extracting only team names (ORG) and players (PERSON)
teams = [ent.text for ent in doc.ents if ent.label_ == "ORG"]
players = [ent.text for ent in doc.ents if ent.label_ == "GPE"]

print("Teams:", teams)
print("Players:", players)
# Out:
# Teams: ['the Animal Birth Control', 'ABC', 'the Supreme Court', 'The Supreme Court']
# Players: ['Delhi']

# %%
# Extracting match details (quantities and dates)
scores = [ent.text for ent in doc.ents if ent.label_ == "QUANTITY"]
date = [ent.text for ent in doc.ents if ent.label_ == "DATE"]

print("Scores and Quantities:", scores)
print("Match Date:", date)
# Out:
# Scores and Quantities: []
# Match Date: ['2023']

# %%
# Adding custom entity
from spacy.tokens import Span

# Adding custom entity for the sponsor
sponsor = "the Supreme Court"
span = Span(doc, len(doc)-1, len(doc), label="SPONSOR")
doc.ents = list(doc.ents) + [span]

# Displaying entities including the new one
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")
# Out:
# Delhi -> GPE
# the Animal Birth Control -> ORG
# ABC -> ORG
# 2023 -> DATE
# the Supreme Court -> ORG
# The Supreme Court -> ORG
#
#  -> SPONSOR

# %% [markdown]
# Key Takeaways:
# NER Pipeline: Pre-trained models identify entities based on context.
#
# Visualization: Use SpaCy’s displacy to visualize named entities.
#
# Filtering: Extract specific types of entities (e.g., teams, players).
#
# Customization: Add new entities to the NER pipeline.

# %%
import spacy  

# Load the small English model
nlp = spacy.load("en_core_web_sm")

# Finance-related text
text = "Microsoft's revenue surged by 15% in Q4 2024, reaching $3.5 billion."

# Processing the text
doc = nlp(text)

# Extracting and displaying named entities
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")
# Out:
# Microsoft -> ORG
# 15% -> PERCENT
# Q4 2024 -> DATE
# $3.5 billion -> MONEY

# %%
# Healthcare-related text
text = "Dr. Emily diagnosed Mark with asthma and prescribed Albuterol."

# Processing the text
doc = nlp(text)

# Displaying named entities
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")
# Out:
# Emily -> PERSON
# Mark -> PERSON
# Albuterol -> GPE

# %%
# Legal-related text
text = "The Supreme Court ruled in favor of case 2023-CV-456, citing the Privacy Act of 1980."

# Processing the text
doc = nlp(text)

# Displaying named entities
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")
# Out:
# The Supreme Court -> ORG
# 2023-CV-456 -> DATE
# the Privacy Act -> LAW
# 1980 -> DATE

# %%
# E-commerce-related text
text = "The Apple iPhone 15 Pro is now available on Amazon for $1199."

# Processing the text
doc = nlp(text)

# Displaying named entities
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")
# Out:
# 15 -> CARDINAL
# Amazon -> ORG
# 1199 -> MONEY

# %%
# Customer feedback text
text = "I am frustrated with the camera quality of my Samsung Galaxy S24."

# Processing the text
doc = nlp(text)

# Displaying named entities
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")
# Out:
# Samsung Galaxy S24 -> ORG

# %%
# Real estate-related text
text = "John bought a 3-bedroom apartment in San Francisco for $850,000 on March 15, 2024."

# Processing the text
doc = nlp(text)

# Displaying named entities
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")
# Out:
# John -> PERSON
# 3 -> CARDINAL
# San Francisco -> GPE
# 850,000 -> MONEY
# March 15, 2024 -> DATE

# %%
# Install SpaCy (if not already installed)
# !pip install spacy

# Install the visualizer (if needed)
# !pip install spacy-streamlit
# Out:
# Requirement already satisfied: spacy in c:\users\a1\jupyter\lib\site-packages (3.8.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\a1\jupyter\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\a1\jupyter\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\a1\jupyter\lib\site-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\a1\jupyter\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\a1\jupyter\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\a1\jupyter\lib\site-packages (from spacy) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\a1\jupyter\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\a1\jupyter\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\a1\jupyter\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\a1\jupyter\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\a1\jupyter\lib\site-packages (from spacy) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\a1\jupyter\lib\site-packages (from spacy) (4.66.4)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\a1\jupyter\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\a1\jupyter\lib\site-packages (from spacy) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\a1\jupyter\lib\site-packages (from spacy) (2.10.4)
# Requirement already satisfied: jinja2 in c:\users\a1\jupyter\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\a1\jupyter\lib\site-packages (from spacy) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\a1\jupyter\lib\site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\a1\jupyter\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\a1\jupyter\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\a1\jupyter\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\a1\jupyter\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\a1\jupyter\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\a1\jupyter\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\a1\jupyter\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\a1\jupyter\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\a1\jupyter\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.6.2)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in c:\users\a1\jupyter\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\a1\jupyter\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\a1\jupyter\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\a1\jupyter\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\a1\jupyter\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\a1\jupyter\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.3.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\a1\jupyter\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\a1\jupyter\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\a1\jupyter\lib\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\a1\jupyter\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\a1\jupyter\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\a1\jupyter\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\a1\jupyter\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Collecting spacy-streamlit
#   Downloading spacy_streamlit-1.0.6-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: streamlit>=1.18.0 in c:\users\a1\jupyter\lib\site-packages (from spacy-streamlit) (1.32.0)
# Requirement already satisfied: spacy<4.0.0,>=3.0.0 in c:\users\a1\jupyter\lib\site-packages (from spacy-streamlit) (3.8.4)
# Requirement already satisfied: pandas in c:\users\a1\jupyter\lib\site-packages (from spacy-streamlit) (2.2.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (4.66.4)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (2.10.4)
# Requirement already satisfied: jinja2 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\a1\jupyter\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-streamlit) (3.5.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\a1\jupyter\lib\site-packages (from streamlit>=1.18.0->spacy-streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\a1\jupyter\lib\site-packages (from streamlit>=1.18.0->spacy-streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\a1\jupyter\lib\site-packages (from streamlit>=1.18.0->spacy-streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\a1\jupyter\lib\site-packages (from streamlit>=1.18.0->spacy-streamlit) (8.1.7)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\a1\jupyter\lib\site-packages (from streamlit>=1.18.0->spacy-streamlit) (10.3.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\a1\jupyter\lib\site-packages (from streamlit>=1.18.0->spacy-streamlit) (4.25.5)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\a1\jupyter\lib\site-packages (from streamlit>=1.18.0->spacy-streamlit) (14.0.2)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\a1\jupyter\lib\site-packages (from streamlit>=1.18.0->spacy-streamlit) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\a1\jupyter\lib\site-packages (from streamlit>=1.18.0->spacy-streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\a1\jupyter\lib\site-packages (from streamlit>=1.18.0->spacy-streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\a1\jupyter\lib\site-packages (from streamlit>=1.18.0->spacy-streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\a1\jupyter\lib\site-packages (from streamlit>=1.18.0->spacy-streamlit) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\a1\jupyter\lib\site-packages (from streamlit>=1.18.0->spacy-streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\a1\jupyter\lib\site-packages (from streamlit>=1.18.0->spacy-streamlit) (6.4.1)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\a1\jupyter\lib\site-packages (from streamlit>=1.18.0->spacy-streamlit) (4.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\a1\jupyter\lib\site-packages (from pandas->spacy-streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\a1\jupyter\lib\site-packages (from pandas->spacy-streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\a1\jupyter\lib\site-packages (from pandas->spacy-streamlit) (2023.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\a1\jupyter\lib\site-packages (from altair<6,>=4.0->streamlit>=1.18.0->spacy-streamlit) (4.19.2)
# Requirement already satisfied: toolz in c:\users\a1\jupyter\lib\site-packages (from altair<6,>=4.0->streamlit>=1.18.0->spacy-streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\a1\jupyter\lib\site-packages (from click<9,>=7.0->streamlit>=1.18.0->spacy-streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\a1\jupyter\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.18.0->spacy-streamlit) (4.0.7)
# Requirement already satisfied: language-data>=1.2 in c:\users\a1\jupyter\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.0.0->spacy-streamlit) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\a1\jupyter\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.0.0->spacy-streamlit) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\a1\jupyter\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.0.0->spacy-streamlit) (2.27.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\a1\jupyter\lib\site-packages (from jinja2->spacy<4.0.0,>=3.0.0->spacy-streamlit) (2.1.3)
# Requirement already satisfied: six>=1.5 in c:\users\a1\jupyter\lib\site-packages (from python-dateutil>=2.8.2->pandas->spacy-streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\a1\jupyter\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacy-streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\a1\jupyter\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacy-streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\a1\jupyter\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacy-streamlit) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\a1\jupyter\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacy-streamlit) (2024.6.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\a1\jupyter\lib\site-packages (from rich<14,>=10.14.0->streamlit>=1.18.0->spacy-streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\a1\jupyter\lib\site-packages (from rich<14,>=10.14.0->streamlit>=1.18.0->spacy-streamlit) (2.15.1)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in c:\users\a1\jupyter\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy<4.0.0,>=3.0.0->spacy-streamlit) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\a1\jupyter\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy<4.0.0,>=3.0.0->spacy-streamlit) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\a1\jupyter\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.0.0->spacy-streamlit) (1.5.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\a1\jupyter\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.0.0->spacy-streamlit) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\a1\jupyter\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.0.0->spacy-streamlit) (5.2.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\a1\jupyter\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.18.0->spacy-streamlit) (4.0.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\a1\jupyter\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.18.0->spacy-streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\a1\jupyter\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.18.0->spacy-streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\a1\jupyter\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.18.0->spacy-streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\a1\jupyter\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.18.0->spacy-streamlit) (0.10.6)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\a1\jupyter\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.0.0->spacy-streamlit) (1.2.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\a1\jupyter\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit>=1.18.0->spacy-streamlit) (0.1.0)
# Downloading spacy_streamlit-1.0.6-py3-none-any.whl (12 kB)
# Installing collected packages: spacy-streamlit
# Successfully installed spacy-streamlit-1.0.6

# %%
import spacy
from spacy import displacy
from spacy.tokens import Span
from spacy.pipeline import EntityRuler

# Load the small English model
nlp = spacy.load("en_core_web_sm")

# %%
text = """
In the IPL 2025 final, Mumbai Indians defeated Royal Challengers Bangalore by 7 wickets. 
Hardik Pandya scored 92 runs off 47 balls, while Virat Kohli's 105 off 60 was in vain. 
The match took place at Narendra Modi Stadium, Ahmedabad, on May 29, 2025.
The title sponsor for this season was Jio, with Tata Motors as the primary partner.
"""

# %%
# Process the text
doc = nlp(text)

# %%
print("\nNER Entities with Labels:\n")
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")
# Out:
# NER Entities with Labels:
#
# 2025 -> DATE
# Mumbai -> GPE
# Indians -> NORP
# Royal Challengers Bangalore -> ORG
# 7 -> CARDINAL
# Hardik Pandya -> PERSON
# 92 -> CARDINAL
# 47 -> CARDINAL
# Virat Kohli's -> ORG
# 105 -> CARDINAL
# 60 -> CARDINAL
# Narendra Modi Stadium, -> FAC
# Ahmedabad -> GPE
# May 29, 2025 -> DATE
# this season -> DATE
# Jio -> PERSON
# Tata Motors -> ORG

# %%
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>In the IPL
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2025
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  final,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indians
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  defeated
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Royal Challengers Bangalore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  wickets. <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hardik Pandya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  scored
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     92
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  runs off
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     47
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  balls, while
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Virat Kohli's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     105
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  off
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     60
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  was in vain. <br>The match took place at
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Narendra Modi Stadium,
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ahmedabad
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 29, 2025
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .<br>The title sponsor for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this season
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  was
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tata Motors
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  as the primary partner.<br></div></span>

# %%
# Adding custom rules
ruler = nlp.add_pipe("entity_ruler", before="ner")

patterns = [
    {"label": "EVENT", "pattern": "IPL Trophy"},
    {"label": "SPONSOR", "pattern": "Jio"},
    {"label": "SPONSOR", "pattern": "Tata Motors"}
]

# Adding patterns to the ruler
ruler.add_patterns(patterns)

# Reprocessing the text
doc = nlp(text)

# Display the new entities
print("\nCustom Entities with Labels:\n")
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")
# Out:
# Custom Entities with Labels:
#
# 2025 -> DATE
# Mumbai -> GPE
# Indians -> NORP
# Royal Challengers Bangalore -> ORG
# 7 -> CARDINAL
# Hardik Pandya -> PERSON
# 92 -> CARDINAL
# 47 -> CARDINAL
# Virat Kohli's -> ORG
# 105 -> CARDINAL
# 60 -> CARDINAL
# Narendra Modi Stadium, -> FAC
# Ahmedabad -> GPE
# May 29, 2025 -> DATE
# this season -> DATE
# Jio -> SPONSOR
# Tata Motors -> SPONSOR

# %%
# Manually adding stadium entity
span = Span(doc, 15, 18, label="STADIUM")
doc.ents = list(doc.ents) + [span]

# Display new entity
print("\nWith Added Stadium Entity:\n")
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")
# Out:
# With Added Stadium Entity:
#
# 2025 -> DATE
# Mumbai -> GPE
# Indians -> NORP
# Royal Challengers Bangalore -> ORG
# 7 -> CARDINAL
# wickets.
#  -> STADIUM
# Hardik Pandya -> PERSON
# 92 -> CARDINAL
# 47 -> CARDINAL
# Virat Kohli's -> ORG
# 105 -> CARDINAL
# 60 -> CARDINAL
# Narendra Modi Stadium, -> FAC
# Ahmedabad -> GPE
# May 29, 2025 -> DATE
# this season -> DATE
# Jio -> SPONSOR
# Tata Motors -> SPONSOR

# %%
# Filtering by specific entity types
players = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]
teams = [ent.text for ent in doc.ents if ent.label_ == "ORG"]

print("\nPlayers:", players)
print("Teams:", teams)
# Out:
# Players: ['Hardik Pandya']
# Teams: ['Royal Challengers Bangalore', "Virat Kohli's"]

# %%
scores = [ent.text for ent in doc.ents if ent.label_ == "QUANTITY"]
date = [ent.text for ent in doc.ents if ent.label_ == "DATE"]
stadium = [ent.text for ent in doc.ents if ent.label_ == "STADIUM"]

print("\nScores:", scores)
print("Match Date:", date)
print("Stadium:", stadium)
# Out:
# Scores: []
# Match Date: ['2025', 'May 29, 2025', 'this season']
# Stadium: ['wickets. \n']

# %%
custom_labels = ["STADIUM", "SPONSOR"]
colors = {"STADIUM": "orange", "SPONSOR": "blue"}

# Custom display
options = {"ents": custom_labels, "colors": colors}
displacy.render(doc, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>In the IPL 2025 final, Mumbai Indians defeated Royal Challengers Bangalore by 7
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wickets.
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STADIUM</span>
# </mark>
# Hardik Pandya scored 92 runs off 47 balls, while Virat Kohli's 105 off 60 was in vain. <br>The match took place at Narendra Modi Stadium, Ahmedabad, on May 29, 2025.<br>The title sponsor for this season was
# <mark class="entity" style="background: blue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SPONSOR</span>
# </mark>
# , with
# <mark class="entity" style="background: blue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tata Motors
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SPONSOR</span>
# </mark>
#  as the primary partner.<br></div></span>
