# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a1 = np.array([1,2,3,4,5])

# %%
plt.plot(a1)

# %%
a2 = np.log2(a1)
plt.plot(a2)

# %%
a2 = np.exp(a1)
plt.plot(a2)

# %%
a2 = a1 ** 4
plt.plot(a2)
