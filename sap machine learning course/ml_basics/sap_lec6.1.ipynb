# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
SEED = 0

# %% [markdown]
# Load Multiclass Iris dataset from scikit-learn

# %%
from sklearn import datasets
iris = datasets.load_iris()
x = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.DataFrame(iris.target)

# %%
x.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, stratify=y)

# %%
#Hyperparameter fine-tuning for LinearSVC on multi-class dataset
parameters = {'penalty' : ['l2'],
              'C' : np.logspace(-2,2,5),
              'max_iter' : list(range(500, 3000, 500)),
              'loss' : ['hinge', 'squared_hinge'],
              'tol' : [1e-4, 1e-5]
              }
gs_clf = GridSearchCV(LinearSVC(multi_class='ovr'),
                      parameters,
                      cv = 5,
                      scoring='f1_macro',verbose=3,
                      n_jobs=-1
                      )
_ = gs_clf.fit(x_train, y_train.values.ravel())

print(gs_clf.best_estimator_)
print(gs_clf.best_params_)
print(gs_clf.best_score_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# LinearSVC(C=np.float64(100.0), loss='hinge', max_iter=2000)
# {'C': np.float64(100.0), 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.0001}
# 0.9753376906318083
# C:\Users\SUYASH\AppData\Roaming\Python\Python313\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
#Hyperparameter fine-tuning for Logistic Regression on multi-class dataset
