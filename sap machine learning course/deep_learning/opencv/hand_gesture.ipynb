# %%
import cv2
import mediapipe as mp
from mediapipe.tasks.python import BaseOptions
from mediapipe.tasks.python.vision import (
    HandLandmarker,
    HandLandmarkerOptions,
    RunningMode
)

# %%
# -----------------------------
# Load Hand Landmarker Model
# -----------------------------
options = HandLandmarkerOptions(
    base_options=BaseOptions(model_asset_path="hand_landmarker.task"),
    running_mode=RunningMode.VIDEO,
    num_hands=2,
    min_hand_detection_confidence=0.75,
    min_hand_presence_confidence=0.75,
    min_tracking_confidence=0.75
)

hand_landmarker = HandLandmarker.create_from_options(options)
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1770192434.080334   87043 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1770192434.094996   87043 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
import mediapipe as mp
print(mp.__version__)
print(dir(mp))
# Out:
# 2026-02-04 13:39:40.134982: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-04 13:39:40.191598: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-04 13:39:41.582675: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 0.10.32
# ['Image', 'ImageFormat', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'tasks']

# %%
# -----------------------------
# Open Webcam
# -----------------------------
cap = cv2.VideoCapture(0)
timestamp = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Convert BGR → RGB
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    mp_image = mp.Image(
        image_format=mp.ImageFormat.SRGB,
        data=rgb_frame
    )

    # Detect hands
    result = hand_landmarker.detect_for_video(mp_image, timestamp)
    timestamp += 1

    # -----------------------------
    # Draw landmarks manually
    # -----------------------------
    if result.hand_landmarks:
        for hand_landmarks in result.hand_landmarks:
            for lm in hand_landmarks:
                h, w, _ = frame.shape
                cx, cy = int(lm.x * w), int(lm.y * h)
                cv2.circle(frame, (cx, cy), 5, (0, 255, 0), -1)

    cv2.imshow("Hand Gesture Detection", frame)

    if cv2.waitKey(1) & 0xFF == 27:  # ESC to quit
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# W0000 00:00:1770192440.999406   87043 landmark_projection_calculator.cc:78] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# QFontDatabase: Cannot find font directory /home/suyashk13/miniconda3/envs/ml/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/suyashk13/miniconda3/envs/ml/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/suyashk13/miniconda3/envs/ml/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/suyashk13/miniconda3/envs/ml/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/suyashk13/miniconda3/envs/ml/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/suyashk13/miniconda3/envs/ml/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/suyashk13/miniconda3/envs/ml/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/suyashk13/miniconda3/envs/ml/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/suyashk13/miniconda3/envs/ml/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/suyashk13/miniconda3/envs/ml/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 21
#      15 mp_image = mp.Image(
#      16     image_format=mp.ImageFormat.SRGB,
#      17     data=rgb_frame
#      18 )
#      20 # Detect hands
# ---> 21 result = hand_landmarker.detect_for_video(mp_image, timestamp)
#      22 timestamp += 1
#      24 # -----------------------------
#      25 # Draw landmarks manually
#      26 # -----------------------------
#
# File ~/miniconda3/envs/ml/lib/python3.10/site-packages/mediapipe/tasks/python/vision/hand_landmarker.py:513, in HandLandmarker.detect_for_video(self, image, timestamp_ms, image_processing_options)
#     506 c_result = HandLandmarkerResultC()
#     508 c_image_processing_options = (
#     509     ctypes.byref(image_processing_options.to_ctypes())
#     510     if image_processing_options
#     511     else None
#     512 )
# --> 513 self._lib.MpHandLandmarkerDetectForVideo(
#     514     self._handle,
#     515     c_image,
#     516     c_image_processing_options,
#     517     timestamp_ms,
#     518     ctypes.byref(c_result),
#     519 )
#     521 py_result = HandLandmarkerResult.from_ctypes(c_result)
#     522 self._lib.MpHandLandmarkerCloseResult(ctypes.byref(c_result))
#
# File ~/miniconda3/envs/ml/lib/python3.10/site-packages/mediapipe/tasks/python/core/serial_dispatcher.py:74, in SerialDispatcher._register_signature.<locals>.shutdown_aware_handler(*args, **kwargs)
#      72   if self._is_closed:
#      73     return
# ---> 74 return handler(*args, **kwargs)
#
# File ~/miniconda3/envs/ml/lib/python3.10/site-packages/mediapipe/tasks/python/core/mediapipe_c_utils.py:142, in CStatusFunction.create_python_wrapper.<locals>.dispatcher_wrapper(*args, **kwargs)
#     139     if error_msg.value is not None:
#     140       lib.MpErrorFree(error_msg)
# --> 142 executor.submit(dispatch_and_free).result()
#
# File ~/miniconda3/envs/ml/lib/python3.10/concurrent/futures/_base.py:453, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     456     raise CancelledError()
#
# File ~/miniconda3/envs/ml/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
