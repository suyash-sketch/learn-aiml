# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread(r'/run/media/suyashk13/New Volume/Suyash/CodingPlatform/Learn AIML/sap machine learning course/deep_learning/opencv/pexels-hiteshchoudhary-18148937.jpg')

# %%
image
# Out:
# array([[[252, 205, 197],
#         [251, 204, 196],
#         [250, 203, 195],
#         ...,
#         [238, 184, 177],
#         [238, 184, 177],
#         [238, 184, 177]],
#
#        [[252, 205, 197],
#         [251, 204, 196],
#         [250, 203, 195],
#         ...,
#         [238, 184, 177],
#         [238, 184, 177],
#         [238, 184, 177]],
#
#        [[252, 205, 197],
#         [251, 204, 196],
#         [250, 203, 195],
#         ...,
#         [238, 184, 177],
#         [238, 184, 177],
#         [238, 184, 177]],
#
#        ...,
#
#        [[ 61,  61,  77],
#         [ 59,  59,  75],
#         [ 61,  61,  77],
#         ...,
#         [106, 102, 113],
#         [104, 100, 111],
#         [ 97,  93, 104]],
#
#        [[ 63,  63,  79],
#         [ 62,  62,  78],
#         [ 64,  64,  80],
#         ...,
#         [ 92,  88,  99],
#         [ 85,  81,  92],
#         [ 77,  73,  84]],
#
#        [[ 58,  58,  74],
#         [ 57,  57,  73],
#         [ 60,  60,  76],
# ...

# %%
t_lower = 50
t_upper = 150

# %%
edge = cv2.Canny(image,t_lower,t_upper)

# %%
# cv2.imshow('original', image)
# cv2.imshow('edge', edge)

plt.imshow(image)
plt.imshow(edge)

# %%
s = "hello w orl  d "

s.replace(" ", "")
# Out:
# 'helloworld'

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
img = cv2.imread('/run/media/suyashk13/New Volume/Suyash/CodingPlatform/Learn AIML/sap machine learning course/deep_learning/opencv/happybaby.jpg')
img.shape
# Out:
# (960, 616, 3)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
gray
# Out:
# array([[  5,   5,   5, ...,  40,  40,  40],
#        [  5,   5,   5, ...,  40,  40,  40],
#        [  5,   5,   5, ...,  39,  39,  39],
#        ...,
#        [116, 118, 121, ...,  94,  94,  93],
#        [116, 119, 123, ...,  94,  93,  93],
#        [117, 121, 126, ...,  94,  93,  93]], shape=(960, 616), dtype=uint8)

# %%
faces = face_cascade.detectMultiScale(gray, 1.1, 4)
faces
# Out:
# array([[ 83, 134, 508, 508]], dtype=int32)

# %%
for (x,y,w,h) in faces:
    ROI = img[y:y+h, x:x+w]
    blur = cv2.GaussianBlur(ROI, (75,75), 0)
    img[y:y+h,x:x+w] = blur
    cv2.rectangle(img, (x,y), (x+w,y+h), (0,0,255),2)

# %%
plt.imshow(img)
