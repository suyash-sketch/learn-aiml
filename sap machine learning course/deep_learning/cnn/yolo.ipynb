# %%
import cv2
from ultralytics import YOLO
import matplotlib.pyplot as plt
import seaborn as sns

# %%
model = YOLO('yolov8n.pt') #smallest lightest fastest model

# %%
#STEP 4: DOWNLOAD A SAMPLE IMAGE
# ===============================
# Download an example image from the internet
# !wget -q https://ultralytics.com/images/bus.jpg -O sample.jpg

# %%
result = model('sample.jpg')
# Out:
# image 1/1 /run/media/suyashk13/New Volume/Suyash/CodingPlatform/Learn AIML/sap machine learning course/deep_learning/cnn/sample.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 76.3ms
# Speed: 6.7ms preprocess, 76.3ms inference, 23.1ms postprocess per image at shape (1, 3, 640, 480)

# %%
annotated_image = result[0].plot()

annotated_image = cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB)
plt.imshow(annotated_image)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
