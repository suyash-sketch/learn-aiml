# %%
# pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in c:\users\a1\appdata\roaming\python\python312\site-packages (0.10.14)
# Requirement already satisfied: absl-py in c:\users\a1\jupyter\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\a1\jupyter\lib\site-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\a1\jupyter\lib\site-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in c:\users\a1\appdata\roaming\python\python312\site-packages (from mediapipe) (0.4.33)
# Requirement already satisfied: jaxlib in c:\users\a1\appdata\roaming\python\python312\site-packages (from mediapipe) (0.4.33)
# Requirement already satisfied: matplotlib in c:\users\a1\jupyter\lib\site-packages (from mediapipe) (3.8.4)
# Requirement already satisfied: numpy in c:\users\a1\jupyter\lib\site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\a1\appdata\roaming\python\python312\site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\a1\jupyter\lib\site-packages (from mediapipe) (4.25.5)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\a1\appdata\roaming\python\python312\site-packages (from mediapipe) (0.5.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\a1\jupyter\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\a1\jupyter\lib\site-packages (from jax->mediapipe) (0.4.1)
# Requirement already satisfied: opt-einsum in c:\users\a1\jupyter\lib\site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.10 in c:\users\a1\jupyter\lib\site-packages (from jax->mediapipe) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\a1\jupyter\lib\site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\a1\jupyter\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\a1\jupyter\lib\site-packages (from matplotlib->mediapipe) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\a1\jupyter\lib\site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\a1\jupyter\lib\site-packages (from matplotlib->mediapipe) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\a1\jupyter\lib\site-packages (from matplotlib->mediapipe) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\a1\jupyter\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\a1\jupyter\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in c:\users\a1\jupyter\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\a1\jupyter\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install screen-brightness-control
# Out:
# Requirement already satisfied: screen-brightness-control in c:\users\a1\jupyter\lib\site-packages (0.23.0)
# Requirement already satisfied: wmi in c:\users\a1\jupyter\lib\site-packages (from screen-brightness-control) (1.5.1)
# Requirement already satisfied: pywin32 in c:\users\a1\jupyter\lib\site-packages (from screen-brightness-control) (305.1)
# Requirement already satisfied: pypiwin32 in c:\users\a1\jupyter\lib\site-packages (from screen-brightness-control) (223)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing Libraries 
import cv2 
import mediapipe as mp 
from math import hypot 
import screen_brightness_control as sbc 
import numpy as np

# %%
# Initializing the Model 
mpHands = mp.solutions.hands 
hands = mpHands.Hands( 
	static_image_mode=False, 
	model_complexity=1, 
	min_detection_confidence=0.75, 
	min_tracking_confidence=0.75, 
	max_num_hands=2) 

Draw = mp.solutions.drawing_utils
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Initializing the Model
# ----> 2 mpHands = mp.solutions.hands
#       3 hands = mpHands.Hands(
#       4 	static_image_mode=False,
#       5 	model_complexity=1,
#       6 	min_detection_confidence=0.75,
#       7 	min_tracking_confidence=0.75,
#       8 	max_num_hands=2)
#      10 Draw = mp.solutions.drawing_utils
#
# AttributeError: module 'mediapipe' has no attribute 'solutions'

# %%
import mediapipe as mp
print(mp.__version__)
# Out:
# 0.10.32

# %%
# Start capturing video from webcam 
cap = cv2.VideoCapture(0) 

while True: 
	# Read video frame by frame 
	_,frame = cap.read() 
	
	#Flip image 
	frame=cv2.flip(frame,1) 
	
	# Convert BGR image to RGB image 
	frameRGB = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB) 
	
	# Process the RGB image 
	Process = hands.process(frameRGB) 
	
	landmarkList = [] 
	# if hands are present in image(frame) 
	if Process.multi_hand_landmarks: 
		# detect handmarks 
		for handlm in Process.multi_hand_landmarks: 
			for _id,landmarks in enumerate(handlm.landmark): 
				# store height and width of image 
				height,width,color_channels = frame.shape 
				
				# calculate and append x, y coordinates 
				# of handmarks from image(frame) to lmList 
				x,y = int(landmarks.x*width),int(landmarks.y*height)			 
				landmarkList.append([_id,x,y]) 
			
			# draw Landmarks 
			Draw.draw_landmarks(frame,handlm,mpHands.HAND_CONNECTIONS) 
	
	# If landmarks list is not empty 
	if landmarkList != []: 
		# store x,y coordinates of (tip of) thumb 
		x_1,y_1 = landmarkList[4][1],landmarkList[4][2] 
		
		# store x,y coordinates of (tip of) index finger 
		x_2,y_2 = landmarkList[8][1],landmarkList[8][2] 
		
		# draw circle on thumb and index finger tip 
		cv2.circle(frame,(x_1,y_1),7,(0,255,0),cv2.FILLED) 
		cv2.circle(frame,(x_2,y_2),7,(0,255,0),cv2.FILLED) 
		
		# draw line from tip of thumb to tip of index finger 
		cv2.line(frame,(x_1,y_1),(x_2,y_2),(0,255,0),3) 
		
		# calculate square root of the sum 
		# of squares of the specified arguments. 
		L = hypot(x_2-x_1,y_2-y_1) 
		
		# 1-D linear interpolant to a function 
		# with given discrete data points 
		# (Hand range 15 - 220, Brightness range 0 - 100), 
		# evaluated at length. 
		b_level = np.interp(L,[15,220],[0,100]) 
	
		# set brightness 
		sbc.set_brightness(int(b_level)) 

	# Display Video and when 'q' is entered, 
	# destroy the window 
	cv2.imshow('Image', frame) 
	if cv2.waitKey(1) & 0xff == ord('q'): 
		break
# Out:
# C:\Users\A1\jupyter\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
